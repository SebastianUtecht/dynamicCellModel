# %% [markdown]
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# from modelAreaCons2ElectricBoogaloo import *
# import os

# folder_name = '13_04_TESTING_AREA'
# try:
#     os.mkdir(folder_name)
# except FileExistsError:
#     pass

# %%
# # output_name = 'wedging_perp'
# # data_dict = np.load("start_conf/last_values.pkl.npy", allow_pickle=True).item()
# # data_dict = np.load("plain_data/data.pkl.npy", allow_pickle=True).item()

# N = 5_00                # Number of cells in the simulation
# R = (N/5)**(1/2)            # Radius of initial cell distribution
# stretch_frac    = 0.15       # Fraction of type 0 cells if using make_random_sphere() cell generation function

# alpha_params = [[(0.0, 'locked'), (0.0, 'locked')],
#                 [(0.0, 'locked'), (0.0, 'locked')]]

# gamma_params = [[(1.0, 'free'), (1.0, 'free')],
#                 [(1.0, 'free'), (1.0, 'free')]]

# target_A = 10.5 / 3
# area_penalty = 1.0

# name = 'd_eff_geomean_nograd_{area_penalty}'.format(area_penalty=area_penalty)

# sim_dict = {
#     # Data and output
#     'output_folder'     : f"{folder_name}/" + f"{name}",                                 # Output folder for simulation data
#     'data'              : (make_sphere_surface_stretch ,[N, stretch_frac, True, R]),     # Tuple containing data information. Can either be a tuple of form (data_gen, *data_gen_args) to generate the data or tuple (p_mask, x, p, q)
#     'yield_every'       : 50,                                               # How often the simulation yields data. 
#     'yield_steps'       : 200,                                             # How many data-yields we want. Total number of timesteps is yield_every * yield_steps

#     # Metasimulational parameters
#     'device'            : 'cuda',           # Device to run the simulation on. 'cuda' or 'cpu'
#     'dtype'             : torch.float,      # Data type for tensors. Either float32 or float64
#     'random_seed'       : 43,               # Random seed for the simulation

#     # Proliferation parameters
#     'prolif_rate'       : [0.00000, 0.00000],           # Cell division probabilities
#     'prolif_delay'      : 0,                # Timesteps before the cells begin proliferating
#     'max_cells'         : 10_000,           # Maximum number of cells in the simulation. When this number is reached the simulation terminates

#     # Main model parameters
#     'lambdas'           : [ [0., 0.8, 0.2, 0.0] ,
#                             [0., 0.8, 0.2, 0.0] ,
#                             [0., 0.8, 0.2, 0.0]],                # Lambda parameters for the simulation
#     'etas'              : [0.0000, 0.0000],                       # Noise level for the simulation
#     'alpha_params'      : alpha_params,                   # Alpha parameters for the simulation
#     'alpha_range'       : 46,                                                       # Range for alpha parameters
#     'gamma_params'      : gamma_params,                           # Gamma parameters for the simulation
#     'target_A'          : target_A,                      # Target area for the cells. Only relevant if lambda_area is not 0
#     'penalize_A'        : area_penalty,                       # Whether to penalize deviations from the target area. Only relevant if lambda_area is not 0 
#     'gamma_range'       : 2.0,                      # Range for gamma parameters
#     'cell_wall_interaction' : 0.0,                  # Strength of cell-wall interactions. 0 for no interaction, 1 for same strength as cell-cell interactions
#     'dt'                : 0.1,                      # Time step for the simulation

#     # Boundary parameters                                                                                                                                                                                                                                     
#     'bound_type'        : None,
#     'bound_extents'     : [24, 4],
#     'bound_move_times'  : [3_000, 17_000],
#     'bound_continuity'  : 5_000,

#     # Stretching parameters
#     'stretch_factor'     : 0.00,
    
#     # cell distance parameters
#     'interaction_dist'  : 3.0,                              # Maximum distance for interactions.
#     'offsets'        : [[0, 0], [0, 0]],         

#     #neighbor debugging params
#     'neighbour_type'    : 'voronoi',                           # Whether to use voronoi or knear neighbors
#     'use_q_mean'        : True,                                   # Whether to use the mean of q_i and q_j for interactions or just q_i
#     'elong_func_type'   : 'sin',                          # Whether to use cos(2theta) or linear function for elongation. 'cos' or 'linear'

#     # Miscellaneous
#     'notes'             : name,  # Notes about the simulation. Will be printed when the simulation starts if verbose and will also be saved in .json output
#     'verbose'           : True,                                         # Verbosity level for the simulation. Set off when debugging
#     }

# run_simulation(sim_dict=sim_dict)                           # Let's run the simulation

# %%
# from modelAreaCons import *
# import os

# %%
# #making a folder for the stuff
# folder_name = '08_04_TESTING_AREA'
# try:
#     os.mkdir(folder_name)
# except FileExistsError:
#     pass


# # output_name = 'wedging_perp'
# # data_dict = np.load("start_conf/last_values.pkl.npy", allow_pickle=True).item()
# data_dict = np.load("plain_data/data.pkl.npy", allow_pickle=True).item()

# alpha_params = [[(0.0, 'locked'), (0.0, 'locked')],
#                 [(0.0, 'locked'), (0.0, 'locked')]]

# # Simulation parameters
# name_lst = ['perp', 'par']
# for name in name_lst:
#     if name == 'perp':
#         gamma_params = [[(.5, 'locked'), (2.0, 'locked')],
#                         [(.5, 'locked'), (2.0, 'locked')]]
#     elif name == 'par':
#         gamma_params = [[(0.5, 'locked'), (2.0, 'locked')],
#                         [(0.5, 'locked'), (2.0, 'locked')]]

#     sim_dict = {
#         # Data and output
#         'output_folder'     : f"{folder_name}/" + '_someelong_contrct_delete_newshit',                                 # Output folder for simulation data
#         'data'              : data_dict, #(make_stretch_plain ,[N, stretch_frac]),     # Tuple containing data information. Can either be a tuple of form (data_gen, *data_gen_args) to generate the data or tuple (p_mask, x, p, q)
#         'yield_every'       : 50,                                               # How often the simulation yields data. 
#         'yield_steps'       : 200,                                             # How many data-yields we want. Total number of timesteps is yield_every * yield_steps

#         # Metasimulational parameters
#         'device'            : 'cuda',           # Device to run the simulation on. 'cuda' or 'cpu'
#         'dtype'             : torch.float,      # Data type for tensors. Either float32 or float64
#         'random_seed'       : 43,               # Random seed for the simulation

#         # Proliferation parameters
#         'prolif_rate'       : [0.00000, 0.00000],           # Cell division probabilities
#         'prolif_delay'      : 0,                # Timesteps before the cells begin proliferating
#         'max_cells'         : 10_000,           # Maximum number of cells in the simulation. When this number is reached the simulation terminates

#         # Main model parameters
#         'lambdas'           : [ [0., 0.6, 0.4, 0.0] ,
#                                 [0., 0.6, 0.4, 0.0] ,
#                                 [0., 0.6, 0.4, 0.0]],                # Lambda parameters for the simulation
#         'etas'              : [0.0000, 0.0000],                       # Noise level for the simulation
#         'alpha_params'      : alpha_params,                   # Alpha parameters for the simulation
#         'alpha_range'       : 46,                                                       # Range for alpha parameters
#         'gamma_params'      : gamma_params,                           # Gamma parameters for the simulation
#         'target_A'          : 10.5 / 3,                      # Target area for the cells. Only relevant if lambda_area is not 0
#         'penalize_A'        : 0.0,                       # Whether to penalize deviations from the target area. Only relevant if lambda_area is not 0 
#         'gamma_range'       : 3.0,                      # Range for gamma parameters
#         'cell_wall_interaction' : 0.0,                  # Strength of cell-wall interactions. 0 for no interaction, 1 for same strength as cell-cell interactions
#         'dt'                : 0.2,                      # Time step for the simulation

#         # Boundary parameters                                                                                                                                                                                                                                     
#         'bound_type'        : None,
#         'bound_extents'     : [24, 4],
#         'bound_move_times'  : [3_000, 17_000],
#         'bound_continuity'  : 5_000,

#         # Stretching parameters
#         'stretch_factor'     : 0.00,
        
#         # cell distance parameters
#         'interaction_dist'  : 3.0,                              # Maximum distance for interactions.
#         'offsets'        : [[0, 0], [0, 0]],         

#         #neighbor debugging params
#         'neighbour_type'    : 'voronoi',                           # Whether to use voronoi or knear neighbors
#         'use_q_mean'        : False,                                   # Whether to use the mean of q_i and q_j for interactions or just q_i

#         # Miscellaneous
#         'notes'             : name,  # Notes about the simulation. Will be printed when the simulation starts if verbose and will also be saved in .json output
#         'verbose'           : True,                                         # Verbosity level for the simulation. Set off when debugging
#         }

#     run_simulation(sim_dict=sim_dict)                           # Let's run the simulation

# %%
# # from modelMoarGamma import *
# from modelTestGammai2cells import *

# %% [markdown]
# ### Running the simulation

# %%
# N = 5_00                # Number of cells in the simulation
# R = (N/5)**(1/2)            # Radius of initial cell distribution
# stretch_frac    = 0.15       # Fraction of type 0 cells if using make_random_sphere() cell generation function

# # Simulation parameters
# sim_dict = {
#     # Data and output
#     'output_folder'     : "eq_gammamean",                                 # Output folder for simulation data
#     'data'              : (make_two_particles_on_string ,[False]),     # Tuple containing data information. Can either be a tuple of form (data_gen, *data_gen_args) to generate the data or tuple (p_mask, x, p, q)
#     'yield_every'       : 10,                                               # How often the simulation yields data. 
#     'yield_steps'       : 1_000,                                             # How many data-yields we want. Total number of timesteps is yield_every * yield_steps

#     # Metasimulational parameters
#     'device'            : 'cpu',           # Device to run the simulation on. 'cuda' or 'cpu'
#     'dtype'             : torch.float,      # Data type for tensors. Either float32 or float64
#     'random_seed'       : 42,               # Random seed for the simulation

#     # Proliferation parameters
#     'prolif_rate'       : [0.00000, 0.00000],           # Cell division probabilities
#     'prolif_delay'      : 0,                # Timesteps before the cells begin proliferating
#     'max_cells'         : 10_000,           # Maximum number of cells in the simulation. When this number is reached the simulation terminates

#     # Main model parameters
#     'lambdas'           : [[0., 0.8, 0.2, 0.0],
#                            [0., 0.8, 0.2, 0.0],
#                            [0., 0.8, 0.2, 0.0]],                # Lambda parameters for the simulation
#     'etas'              : [0.000, 0.000],                       # Noise level for the simulation
#     'alpha_params'      : [[(0.0, 'locked'), (0.0, 'locked')],
#                            [(0.0, 'locked'), (0.0, 'locked')]],                     # Alpha parameters for the simulation
#     'alpha_range'       : 45,                                                       # Range for alpha parameters
#     'gamma_params'      : [(1., 'locked'), (1.5, 'locked')],                           # Gamma parameters for the simulation
#     'gamma_range'       : 1.5,                      # Range for gamma parameters
#     'gamma_mean_bool'   : False,                    # Whether to use the mean of gamma_i and gamma_j for interactions or just gamma_i
#     'cell_wall_interaction' : 0.0,                  # Strength of cell-wall interactions. 0 for no interaction, 1 for same strength as cell-cell interactions
#     'dt'                : 0.2,                      # Time step for the simulation

#     # Boundary parameters                                                                                                                                                                                                                                     
#     'bound_type'        : None,
#     'bound_extents'     : [24, 4],
#     'bound_move_times'  : [3_000, 17_000],
#     'bound_continuity'  : 5_000,

#     # Stretching parameters
#     'stretch_factor'     : 0.02,
    
#     # cell distance parameters  # Maximum distance for interactions.
#     'offsets'        : [[0, 0], [0, 0]],         
#     'interaction_dist'  : 3.0,                            

#     # Miscellaneous
#     'notes'             : f'shit_still_fucked_yo_2_electric_boogaloo',  # Notes about the simulation. Will be printed when the simulation starts if verbose and will also be saved in .json output
#     'verbose'           : True,                                         # Verbosity level for the simulation. Set off when debugging
#     }

# run_simulation(sim_dict=sim_dict)                           # Let's run the simulation

# %%
# from model1404RepoVersion import *
from model1404AFWExportNoLearn import *
import os

folder_name = '16_06_MEETINGTESTS'
try:
    os.mkdir(folder_name)
except FileExistsError:
    pass

# %%
# Data
# data_dict = np.load("plain_data/data.pkl.npy", allow_pickle=True).item()
# data_dict = np.load("start_conf/last_values.pkl.npy", allow_pickle=True).item()
data_dict = (make_stretch_plain, (10, 0.0))
# data = np.load("start_conf/last_values.pkl.npy", allow_pickle=True)
# data_dict = np.load("tenxten_sheet.pkl", allow_pickle=True)
# data_dict['q'][:] = np.array([0,1,0])
# data_dict = (make_two_particles_on_string, (2,))



# data_dict = np.load('schausers_data_3/data.pkl', allow_pickle=True)
# data_dict['q'][:] = np.array([0,1,0])

# %%
# General parameters
neighbour_type = 'voronoi'
elong_func_type = 'cos'
q_mean = True

#Stretching
stretch_factor = 0.000
stretch_stop_ext = 101.0
just_move_bool = True

#gamma params
# gamma_params = [(1.0, 'locked'), (1.0, 'locked')]
gamma_params = (1.0, 'locked')
gamma_diff = 0.0
gamma_range = 2.0
gamma_update_speed = 1.0

#alpha params
# alpha_params = [[(0.0, 'locked'), (-0.0, 'locked')],
                # [(0.0, 'locked'), (-0.0, 'locked')]]

par_angle = -30.0
perp_angle = 30.0

alpha_params = [(par_angle, 'locked'), (perp_angle, 'locked')]

alpha_range         = 45.0
wedge_pcp           = True
debug_wedge         = False
old_rotation        = False
individual_rotation = False

# name = f'par_{par_angle}_perp_{perp_angle}_qwegde_{wedge_pcp}_indi_{individual_rotation}'
eta = 0.000
polar_etas = 10.
dt = 0.01
name = f'pringle_dt_{dt}_polnoise_{polar_etas}'
# name = f'test_poloise'

# Simulation parameters
sim_dict = {
    # Data and output
    'output_folder'     : folder_name + f'/{name}',                         # Output folder for simulation data
    'data'              : data_dict,                                        # Tuple containing data information. Can either be a tuple of form (data_gen, *data_gen_args) to generate the data or tuple (p_mask, x, p, q)
    'yield_every'       : 50,                                               # How often the simulation yields data. 
    'yield_steps'       : 1_000,                                             # How many data-yields we want. Total number of timesteps is yield_every * yield_steps

    # Metasimulational parameters
    'device'            : 'cpu',           # Device to run the simulation on. 'cuda' or 'cpu'
    'dtype'             : torch.float,      # Data type for tensors. Either float32 or float64
    'random_seed'       : 50,               # Random seed for the simulation
    'k'                 : 18,                # Number of nearest neighbors to consider  

    # Proliferation parameters
    'prolif_rate'       : 0.0, #[0.0000, 0.0000],           # Cell division probabilities
    'prolif_delay'      : 0,                # Timesteps before the cells begin proliferating
    'max_cells'         : 20_000,           # Maximum number of cells in the simulation. When this number is reached the simulation terminates

    # Main model parameters
    'lambdas'           :   [0.,  .1, .9, 0.0],
                            # [0., .8, 0.2, 0.0],
                            # [0., .8, 0.2, 0.0]],                      # Lambda parameters for the simulation
    'etas'              : eta, #[0.0000, 0.0000],                       # Noise level for the simulation
    'polar_etas'        : polar_etas,                                   # Noise level for polarity updates
    'alpha_params'      : alpha_params,                                 # Alpha parameters for the simulation
    'alpha_range'       : alpha_range,                                  # Range for alpha parameters
    'gamma_params'      : gamma_params,                                 # Gamma parameters for the simulation
    'gamma_range'       : gamma_range,                                  # Range for gamma parameters
    'cell_wall_interaction' : 0.0,                                      # Strength of cell-wall interactions. 0 for no interaction, 1 for same strength as cell-cell interactions
    'dt'                : dt,                                          # Time step for the simulation
    'nematic_pcp'       : False,                                        # Whether planar cell polarity is nematic (True) or vectorial (False)
    'update_cells_bools': [True, True],                                 # List of booleans determining whether to update the parameters for each cell type
    'wedge_pcp'         : wedge_pcp,                                    # Whether to wedge the cells based on their PCP. Only relevant if update_cells_bools is True
    'individual_rotation' : individual_rotation,                        # Whether to apply the wedging rotations individually to each neighbor based on their relative position, or to apply a single rotation based on the mean neighbor position. Only relevant if wedge_pcp is True
    'old_rotation'      : old_rotation,                                 # Whether to use the old method of calculating the rotated ABP vectors, which was based on a simple tangent calculation, or the new method, which uses Rodrigues' rotation formula. The new method is more accurate and can handle larger angles, but the old method is faster and can be sufficient for small angles. Only relevant if alpha parameters are non-zero
    
    # Boundary parameters                                                                                                                                                                                                                                     
    'bound_type'        : None, #'planes',
    'bound_extents'     : [24, 6],
    'bound_move_times'  : [3_000, 17_000],
    'bound_continuity'  : 5_000,
    'stretch_bound_axis': 0,                # The axis along which the stretch is applied. 0 for x, 1 for y, 2 for z. Only relevant if stretch_factor is not 0

    # Stretching parameters
    'stretch_factor'    : stretch_factor,
    'stretch_stop_ext'  : stretch_stop_ext,
    'just_move_bool'    : just_move_bool,                    # Whether to just move the cells according to the stretching without applying any of the other forces. Useful for debugging the stretching implementation
    'stretch_time_stop' : 20_000,                    # Time step at which to stop the stretching. Only relevant if stretch_factor is not 0
    
    #neighbor debugging params
    'use_q_mean'        : q_mean,                                   # Whether to use the mean of q_i and q_j for interactions or just q_i
    'elong_func_type'   : elong_func_type,                          # Whether to use cos(2theta) or linear function for elongation. 'cos' or 'linear'

    #Means of aligning gammas
    'use_gamma_mean'    : True,                              # Whether to use the mean of gamma_i and gamma_j for interactions or just gamma_i
    'gamma_diff_penalty': gamma_diff,                      # Penalty for differences in gamma between neighboring cells. Only relevant if use_gamma_mean is True
    'gamma_update_speed': gamma_update_speed,              # Speed at which gammas are updated based on the difference between neighboring gammas. Only relevant if use_gamma_mean is True
    'screen_out_defects': False,                    
    # Whether to screen out defects in the neighbor calculations. Only relevant if neighbour_type is 'voronoi'

    # Miscellaneous
    'notes'             : name,  # Notes about the simulation. Will be printed when the simulation starts if verbose and will also be saved in .json output
    'verbose'           : True,                                                                     # Verbosity level for the simulation. Set off when debugging
    }

run_simulation(sim_dict=sim_dict)                                                               # Let's run the simulation
# Out:
# Using data generation function
# Starting simulation with notes:
# pringle_dt_0.01
# Found max safe batch size: 1024
# Using batch size: 1024 for true neighbor search.
# Using new rotation method
# Found max safe batch size: 1024
# Using batch size: 1024 for true neighbor search.
# Using new rotation method
# Simulation done, saved 1000 datapoints)   (100 cells)
# Took 2045.3489308357239 seconds

# %%
# # General parameters
# neighbour_type = 'voronoi'
# elong_func_type = 'cos'
# q_mean = True


# #Stretching
# stretch_factor = 0.000#alpha params
# alpha_params = [[(0.0, 'locked'), (-0.0, 'locked')],
                # [(0.0, 'locked'), (-0.0, 'locked')]]
# stretch_stop_ext = 101.0
# just_move_bool = True

# #gamma params
# gamma_params = [(1.0, 'locked'), (1.0, 'locked')]
# gamma_diff = 0.0
# gamma_range = 2.0
# gamma_update_speed = 1.0

# #alpha params
# alpha_params = [[(-30.0, 'locked'), (30.0, 'locked')],
#                 [(-30.0, 'locked'), (30.0, 'locked')]]
# alpha_range = 45.0
# wedge_pcp = True
# debug_wedge = True

# name = f'pringle_x_polar_no_fuckery'

# # Simulation parameters
# sim_dict = {
#     # Data and output
#     'output_folder'     : folder_name + f'/{name}',                         # Output folder for simulation data
#     'data'              : data_dict,                                        # Tuple containing data information. Can either be a tuple of form (data_gen, *data_gen_args) to generate the data or tuple (p_mask, x, p, q)
#     'yield_every'       : 50,                                               # How often the simulation yields data. 
#     'yield_steps'       : 2_00,                                             # How many data-yields we want. Total number of timesteps is yield_every * yield_steps

#     # Metasimulational parameters
#     'device'            : 'cuda',           # Device to run the simulation on. 'cuda' or 'cpu'
#     'dtype'             : torch.float,      # Data type for tensors. Either float32 or float64
#     'random_seed'       : 43,               # Random seed for the simulation
#     'k'                 : 12,                # Number of nearest neighbors to consider  

#     # Proliferation parameters
#     'prolif_rate'       : [0.0000, 0.0000],           # Cell division probabilities
#     'prolif_delay'      : 0,                # Timesteps before the cells begin proliferating
#     'max_cells'         : 20_000,           # Maximum number of cells in the simulation. When this number is reached the simulation terminates

#     # Main model parameters
#     'lambdas'           :   [[0.,  .8, 0.2, 0.0],
#                             [0., .8, 0.2, 0.0],
#                             [0., .8, 0.2, 0.0]],                # Lambda parameters for the simulation
#     'etas'              :  [0.0001, 0.0001],                       # Noise level for the simulation
#     'alpha_params'      : alpha_params,                    # Alpha parameters for the simulation
#     'alpha_range'       : alpha_range,                                                       # Range for alpha parameters
#     'gamma_params'      : gamma_params,                           # Gamma parameters for the simulation
#     'gamma_range'       : gamma_range,                      # Range for gamma parameters
#     'cell_wall_interaction' : 0.0,                  # Strength of cell-wall interactions. 0 for no interaction, 1 for same strength as cell-cell interactions
#     'dt'                : 0.2,                      # Time step for the simulation
#     'nematic_pcp'       : False,                    # Whether planar cell polarity is nematic (True) or vectorial (False)
#     'update_cells_bools': [True, True],           # List of booleans determining whether to update the parameters for each cell type
#     'screen_out_defects': False,                    # Whether to screen out defects in the neighbor calculations. Only relevant if neighbour_type is 'voronoi'
#     'wedge_pcp'         : wedge_pcp,                    # Whether to apply wedging rotations to the PCP as well as the ABP. Only relevant if alpha parameters are non-zero
#     'debug_wedge'       : debug_wedge,                    # Whether to print debugging information about wedge rotation components

#     # Boundary parameters                                                                                                                                                                                                                                     
#     'bound_type'        : None, #'planes',
#     'bound_extents'     : [24, 6],
#     'bound_move_times'  : [3_000, 17_000],
#     'bound_continuity'  : 5_000,
#     'stretch_bound_axis': 0,                # The axis along which the stretch is applied. 0 for x, 1 for y, 2 for z. Only relevant if stretch_factor is not 0

#     # Stretching parameters
#     'stretch_factor'    : stretch_factor,
#     'stretch_stop_ext'  : stretch_stop_ext,
#     'just_move_bool'    : just_move_bool,                    # Whether to just move the cells according to the stretching without applying any of the other forces. Useful for debugging the stretching implementation
#     'stretch_time_stop' : 20_000,                    # Time step at which to stop the stretching. Only relevant if stretch_factor is not 0
    
#     #neighbor debugging params
#     'use_q_mean'        : q_mean,                                   # Whether to use the mean of q_i and q_j for interactions or just q_i
#     'elong_func_type'   : elong_func_type,                          # Whether to use cos(2theta) or linear function for elongation. 'cos' or 'linear'

#     #Means of aligning gammas
#     'use_gamma_mean'    : True,                              # Whether to use the mean of gamma_i and gamma_j for interactions or just gamma_i
#     'gamma_diff_penalty': gamma_diff,                      # Penalty for differences in gamma between neighboring cells. Only relevant if use_gamma_mean is True
#     'gamma_update_speed': gamma_update_speed,              # Speed at which gammas are updated based on the difference between neighboring gammas. Only relevant if use_gamma_mean is True

#     # Miscellaneous
#     'notes'             : name,  # Notes about the simulation. Will be printed when the simulation starts if verbose and will also be saved in .json output
#     'verbose'           : True,                                                                     # Verbosity level for the simulation. Set off when debugging
#     }

# run_simulation(sim_dict=sim_dict)                                                               # Let's run the simulation
