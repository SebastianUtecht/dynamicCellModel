# %% [markdown]
# ### Imports

# %%
from modelMoarGamma import *

# %% [markdown]
# ### Running the simulation

# %%
N = 5_000                # Number of cells in the simulation
R = N**(1/3)            # Radius of initial cell distribution
type0_frac    = 1       # Fraction of type 0 cells if using make_random_sphere() cell generation function

# Simulation parameters
sim_dict = {
    # Data and output
    'output_folder'     : "gamma_alpha_0",                                 # Output folder for simulation data
    'data'              : (make_random_sphere ,[N, type0_frac, R]),     # Tuple containing data information. Can either be a tuple of form (data_gen, *data_gen_args) to generate the data or tuple (p_mask, x, p, q)
    'yield_every'       : 50,                                               # How often the simulation yields data. 
    'yield_steps'       : 1_000,                                             # How many data-yields we want. Total number of timesteps is yield_every * yield_steps

    # Metasimulational parameters
    'device'            : 'cuda',           # Device to run the simulation on. 'cuda' or 'cpu'
    'dtype'             : torch.float,      # Data type for tensors. Either float32 or float64
    'random_seed'       : 42,               # Random seed for the simulation

    # Proliferation parameters
    'prolif_rate'       : 0.0000,           # Cell division probabilities
    'prolif_delay'      : 0,                # Timesteps before the cells begin proliferating
    'max_cells'         : 10_000,           # Maximum number of cells in the simulation. When this number is reached the simulation terminates

    # Main model parameters
    'lambdas'           : [0., 0.8, 0.2, 0.],       # Lambda parameters for the simulation
    'etas'              : 0.0000,                   # Noise level for the simulation
    'alpha_params'      : [(0.0, 'free'), (0.0, 'free')],                         # Alpha parameters for the simulation
    'alpha_range'       : 45,                      # Range for alpha parameters
    'gamma_params'      : [1.0, 'free'],          # Gamma parameters for the simulation
    'gamma_range'       : 1.5,                      # Range for gamma parameters
    'cell_wall_interaction' : 0.0,                  # Strength of cell-wall interactions. 0 for no interaction, 1 for same strength as cell-cell interactions
    'dt'                : 0.2,                      # Time step for the simulation

    # Boundary parameters
    'bound_radius'      : None,                     # If set, we enact boundary conditions on a spherical region of this radius
    
    # cell distance parameters
    'interaction_dist'  : 3.0,                      # Maximum distance for interactions.
    'offsets'        : [[0, 0], [0, 0]],         

    
    # Miscellaneous
    'notes'             : f'shit_be_slightly_less_fucked',  # Notes about the simulation. Will be printed when the simulation starts if verbose and will also be saved in .json output
    'verbose'           : True,                     # Verbosity level for the simulation. Set off when debugging
    }

run_simulation(sim_dict=sim_dict)                   # Let's run the simulation
# Out:
# Using data generation function
# Starting simulation with notes:
# shit_be_slightly_less_fucked
# Found max safe batch size: 16384
# Using batch size: 16384 for true neighbor search.
# Running 502 of 1000   (25100 of 50000)   (5000 cells)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 46
#       5 # Simulation parameters
#       6 sim_dict = {
#       7     # Data and output
#       8     'output_folder'     : "gamma_alpha_0",                                 # Output folder for simulation data
#    (...)
#      43     'verbose'           : True,                     # Verbosity level for the simulation. Set off when debugging
#      44     }
# ---> 46 run_simulation(sim_dict=sim_dict)                   # Let's run the simulation
#
# File ~/Desktop/dynamicCellModel/dynamicCellModel/code/modelMoarGamma.py:957, in run_simulation(sim_dict)
#     954 t1 = time() # We timing stuff
#     956 # Saving data at intervals specified by yield_every:
# --> 957 for xx, pp, qq, pp_mask, alpha_parpar, alpha_perpperp, gammagamma, energyenergy in itertools.islice(runner, yield_steps):
#     958     i += 1
#     959     if verbose:
#
# File ~/Desktop/dynamicCellModel/dynamicCellModel/code/modelMoarGamma.py:722, in Simulation.simulation(self, x, p, q, p_mask, alpha_par, alpha_perp, gamma)
#     720 tstep = 0
#     721 while True:
# --> 722     x, p, q, p_mask, alpha_par, alpha_perp, gamma, energy = self.time_step(x, p, q, p_mask, alpha_par, alpha_perp, gamma, tstep)        #Advancing the simulation one timestep
#     724     tstep += 1
#     725     self.tstep = tstep
#
# File ~/Desktop/dynamicCellModel/dynamicCellModel/code/modelMoarGamma.py:679, in Simulation.time_step(self, x, p, q, p_mask, alpha_par, alpha_perp, gamma, tstep)
#     676             alpha_perp[p_mask == i] = torch.clamp(alpha_perp[p_mask == i], self.alpha_range[0], self.alpha_range[1])
#     678         if self.gamma_bool_lst[i]:
# --> 679             gamma[p_mask == i] += -gamma.grad[p_mask == i] * self.dt + eta * torch.empty(*gamma[p_mask == i].shape, dtype=self.dtype, device=self.device).normal_() * self.sqrt_dt
#     680             gamma[p_mask == i] = torch.clamp(gamma[p_mask == i], self.gamma_range[0], self.gamma_range[1])
#     682 # We zero out the gradients for next time step
#
# KeyboardInterrupt:
