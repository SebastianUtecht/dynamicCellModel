# %% [markdown]
# ### Imports

# %%
from model import *

# %% [markdown]
# ### Running the simulation

# %%
N = 2_000               # Number of cells in the simulation
R = N**(1/3)            # Radius of initial cell distribution
type0_frac    = 1       # Fraction of type 0 cells if using make_random_sphere() cell generation function

# Simulation parameters
sim_dict = {
    # Data and output
    'output_folder'     : "bounds",                                         # Output folder for simulation data
    'data'              : (make_random_sphere ,[N, (1.0-type0_frac), R]),   # Tuple containing data information. Can either be a tuple of form (data_gen, *data_gen_args) to generate the data or tuple (p_mask, x, p, q)
    'yield_every'       : 50,                                               # How often the simulation yields data. 
    'yield_steps'       : 5_00,                                             # How many data-yields we want. Total number of timesteps is yield_every * yield_steps

    # Stuff for tensors
    'device'            : 'cuda',           # Device to run the simulation on. 'cuda' or 'cpu'
    'dtype'             : torch.float,      # Data type for tensors. Either float32 or float64

    # Proliferation parameters
    'prolif_rate'       : 0.0001,           # Cell division probabilities
    'prolif_delay'      : 0,                # Timesteps before the cells begin proliferating
    'max_cells'         : 10_000,           # Maximum number of cells in the simulation. When this number is reached the simulation terminates

    # Simulation parameters
    'dt'                : 0.2,              # Time step for the simulation
    'eta'               : 0.05,             # Noise level for the simulation
    'lambdas'           : [0, 1.0, 0, 0],   # Lambda parameters for the simulation
    'bound_radius'      : None,             # If set, we enact boundary conditions on a spherical region of this radius

    # Miscellaneous
    'notes'             : f'Running test w. bounds',    # Notes about the simulation. Will be printed when the simulation starts if verbose and will also be saved in .json output
    'verbose'           : True,                         # Verbosity level for the simulation. Set off when debugging
    'random_seed'       : 42,                           # Random seed for the simulation
    }

run_simulation(sim_dict=sim_dict)           # Let's run the simulation
# Out:
# Using data generation function
# Starting simulation with notes:
# Running test w. bounds
# Running 117 of 500   (5850 of 25000)   (3547 cells)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 33
#       3 type0_frac    = 1
#       5 sim_dict = {
#       6     # Data and output
#       7     'output_folder'     : "bounds",
#    (...)
#      30     'random_seed'       : 42,
#      31     }
# ---> 33 run_simulation(sim_dict=sim_dict)
#
# File c:\Users\s_ute\OneDrive\Dokumenter\Uni\RA\vidScripts\Vid6\model.py:342, in run_simulation(sim_dict)
#     339 i = 0
#     340 t1 = time()
# --> 342 for xx, pp, qq, pp_mask in itertools.islice(runner, yield_steps):
#     343     i += 1
#     344     if verbose:
#
# File c:\Users\s_ute\OneDrive\Dokumenter\Uni\RA\vidScripts\Vid6\model.py:228, in Simulation.simulation(self, x, p, q, p_mask)
#     226 while True:
#     227     tstep += 1
# --> 228     x, p, q, p_mask = self.time_step(x, p, q, p_mask, tstep)
#     230     if tstep % self.yield_every == 0 or len(x) > self.max_cells:
#     231         xx = x.detach().to("cpu").numpy().copy()
#
# File c:\Users\s_ute\OneDrive\Dokumenter\Uni\RA\vidScripts\Vid6\model.py:200, in Simulation.time_step(self, x, p, q, p_mask, tstep)
#     197 idx = self.idx
#     199 # Calculate potential
# --> 200 V = self.potential(x, p, q, p_mask, idx)
#     202 # Backpropagation
#     203 V.backward()
#
# File c:\Users\s_ute\OneDrive\Dokumenter\Uni\RA\vidScripts\Vid6\model.py:103, in Simulation.potential(self, x, p, q, p_mask, idx)
#     101 def potential(self, x, p, q, p_mask, idx):
# --> 103     d, dx, idx, voronoi_mask = self.get_neighbors(x)
#     105     if isinstance(p_mask, torch.Tensor):
#     106         # Making interaction mask
#     107         assert torch.numel(self.lambdas) == 12, "Expected 3*4 lambda values"
#
# File c:\Users\s_ute\OneDrive\Dokumenter\Uni\RA\vidScripts\Vid6\model.py:87, in Simulation.get_neighbors(self, x)
#      84 idx = idx[:, :m]
#      86 # Normalise dx
# ---> 87 d = torch.sqrt(torch.sum(dx**2, dim=2))
#      88 dx = dx / d[:, :, None]
#      90 return d, dx, idx, voronoi_mask
#
# File c:\Users\s_ute\anaconda3\envs\masters_env\Lib\site-packages\torch\_tensor.py:34, in _handle_torch_function_and_wrap_type_error_to_not_implemented.<locals>.wrapped(*args, **kwargs)
#      31 def _handle_torch_function_and_wrap_type_error_to_not_implemented(f):
#      32     assigned = functools.WRAPPER_ASSIGNMENTS
# ---> 34     @functools.wraps(f, assigned=assigned)
#      35     def wrapped(*args, **kwargs):
#      36         try:
#      37             # See https://github.com/pytorch/pytorch/issues/75462
#      38             if has_torch_function(args):
#
# KeyboardInterrupt:
