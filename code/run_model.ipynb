# %% [markdown]
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from modelAreaCons import *

# %%
N = 5_00                # Number of cells in the simulation
R = (N/5)**(1/2)            # Radius of initial cell distribution
stretch_frac    = 0.1       # Fraction of type 0 cells if using make_random_sphere() cell generation function

# Simulation parameters
sim_dict = {
    # Data and output
    'output_folder'     : "test_areacons_gammafree",                                 # Output folder for simulation data
    'data'              : (make_sphere_surface_stretch ,[N, stretch_frac, True, R]),     # Tuple containing data information. Can either be a tuple of form (data_gen, *data_gen_args) to generate the data or tuple (p_mask, x, p, q)
    'yield_every'       : 50,                                               # How often the simulation yields data. 
    'yield_steps'       : 1_000,                                             # How many data-yields we want. Total number of timesteps is yield_every * yield_steps

    # Metasimulational parameters
    'device'            : 'cuda',           # Device to run the simulation on. 'cuda' or 'cpu'
    'dtype'             : torch.float,      # Data type for tensors. Either float32 or float64
    'random_seed'       : 42,               # Random seed for the simulation

    # Proliferation parameters
    'prolif_rate'       : [0.00000, 0.00000],           # Cell division probabilities
    'prolif_delay'      : 0,                # Timesteps before the cells begin proliferating
    'max_cells'         : 10_000,           # Maximum number of cells in the simulation. When this number is reached the simulation terminates

    # Main model parameters
    'lambdas'           : [[0., 0.8, 0.2, 0.0],
                           [0., 0.8, 0.2, 0.0],
                           [0., 0.8, 0.2, 0.0]],                # Lambda parameters for the simulation
    'etas'              : [0.000, 0.000],                       # Noise level for the simulation
    'alpha_params'      : [[(0.0, 'locked'), (0.0, 'locked')],
                           [(0.0, 'locked'), (0.0, 'locked')]],                     # Alpha parameters for the simulation
    'alpha_range'       : 45,                                                       # Range for alpha parameters
    'gamma_params'      : [[(1.0, 'locked'), (1.0, 'locked')],
                           [(1.0, 'locked'), (1.0, 'locked')]],                           # Gamma parameters for the simulation
    'target_A'          : 10.5 * 1/3,                      # Target area for the cells. Only relevant if lambda_area is not 0
    'penalize_A'        : 0.01,                       # Whether to penalize deviations from the target area. Only relevant if lambda_area is not 0 
    'gamma_range'       : 1.5,                      # Range for gamma parameters
    'cell_wall_interaction' : 0.0,                  # Strength of cell-wall interactions. 0 for no interaction, 1 for same strength as cell-cell interactions
    'dt'                : 0.2,                      # Time step for the simulation

    # Boundary parameters                                                                                                                                                                                                                                     
    'bound_type'        : None,
    'bound_extents'     : [24, 4],
    'bound_move_times'  : [3_000, 17_000],
    'bound_continuity'  : 5_000,

    # Stretching parameters
    'stretch_factor'     : 0.00,
    
    # cell distance parameters
    'interaction_dist'  : 3.0,                              # Maximum distance for interactions.
    'offsets'        : [[0, 0], [0, 0]],         

    # Miscellaneous
    'notes'             : f'shit_still_fucked_yo_2_electric_boogaloo',  # Notes about the simulation. Will be printed when the simulation starts if verbose and will also be saved in .json output
    'verbose'           : True,                                         # Verbosity level for the simulation. Set off when debugging
    }

run_simulation(sim_dict=sim_dict)                           # Let's run the simulation
# Out:
# Using data generation function
# Starting simulation with notes:
# shit_still_fucked_yo_2_electric_boogaloo
# Found max safe batch size: 2048
# Using batch size: 2048 for true neighbor search.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 57
#       5 # Simulation parameters
#       6 sim_dict = {
#       7     # Data and output
#       8     'output_folder'     : "test_areacons_gammafree",                                 # Output folder for simulation data
#    (...)
#      54     'verbose'           : True,                                         # Verbosity level for the simulation. Set off when debugging
#      55     }
# ---> 57 run_simulation(sim_dict=sim_dict)                           # Let's run the simulation
#
# File ~/Desktop/dynamicCellModel/dynamicCellModel/code/modelAreaCons.py:1118, in run_simulation(sim_dict)
#    1115 t1 = time() # We timing stuff
#    1117 # Saving data at intervals specified by yield_every:
# -> 1118 for xx, pp, qq, pp_mask, alpha_parpar, alpha_perpperp, gamma_parpar, gamma_perpperp, energyenergy in itertools.islice(runner, yield_steps):
#    1119     i += 1
#    1120     if verbose:
#
# File ~/Desktop/dynamicCellModel/dynamicCellModel/code/modelAreaCons.py:802, in Simulation.simulation(self, x, p, q, p_mask, alpha_par, alpha_perp, gamma_par, gamma_perp)
#     800 tstep = 0
#     801 while True:
# --> 802     x, p, q, p_mask, alpha_par, alpha_perp, gamma_par, gamma_perp, energy = self.time_step(x, p, q, p_mask, alpha_par, alpha_perp, gamma_par, gamma_perp, tstep)        #Advancing the simulation one timestep
#     804     tstep += 1
#     805     self.tstep = tstep
#
# File ~/Desktop/dynamicCellModel/dynamicCellModel/code/modelAreaCons.py:729, in Simulation.time_step(self, x, p, q, p_mask, alpha_par, alpha_perp, gamma_par, gamma_perp, tstep)
#     726 d, dx, idx, z_mask = self.get_neighbors_vor(x, p, q, gamma_par, gamma_perp, k=self.k)
#     728 # Calculate potential
# --> 729 V, Vi = self.potential(x, p, q, p_mask,
#     730                     alpha_par, alpha_perp, gamma_par, gamma_perp,
#     731                     d, dx, idx, z_mask)
#     733 # Backpropagation
#     734 V.backward()
#
# File ~/Desktop/dynamicCellModel/dynamicCellModel/code/modelAreaCons.py:620, in Simulation.potential(self, x, p, q, p_mask, alpha_par, alpha_perp, gamma_par, gamma_perp, d, dx, idx, z_mask)
#     617 Vij_sum = torch.sum(Vij)
#     619     # if self.penalize_A:
# --> 620 Ai = self.calculate_area(d, dx, q_mean, perp_dir, z_mask)
#     621     # A_penalty = self.penalize_A * (Ai - self.target_A)**2
#     622     # Vij_sum += A_penalty.sum()
#     624 if self.tstep > 1_000:
#     625     # Boundary conditions
#
# File ~/Desktop/dynamicCellModel/dynamicCellModel/code/modelAreaCons.py:156, in Simulation.calculate_area(self, d, dx, q_mean, perp_dir, z_mask)
#     154 angles = torch.atan2(y, x) # We can use any component here, since x and y are parallel to q_mean and perp_dir respectively
#     155 sort_idx = torch.argsort(angles, dim=1)
# --> 156 rij = torch.gather(rij, 1, sort_idx[:,:,None].expand(-1, -1, 3))
#     157 z_mask = torch.gather(z_mask, 1, sort_idx)
#     158 area = 0.166 * torch.sum(torch.linalg.norm(torch.cross(rij[:, :-1], rij[:, 1:], dim=2), dim=2) * z_mask[:, :-1] * z_mask[:, 1:], dim=1)
#
# RuntimeError: expand(torch.cuda.LongTensor{[500, 8, 1, 3]}, size=[-1, -1, 3]): the number of sizes provided (3) must be greater or equal to the number of dimensions in the tensor (4)

# %%
# from modelMoarGamma import *
from modelTestGammai2cells import *

# %% [markdown]
# ### Running the simulation

# %%
N = 5_00                # Number of cells in the simulation
R = (N/5)**(1/2)            # Radius of initial cell distribution
stretch_frac    = 0.15       # Fraction of type 0 cells if using make_random_sphere() cell generation function

# Simulation parameters
sim_dict = {
    # Data and output
    'output_folder'     : "eq_gammamean",                                 # Output folder for simulation data
    'data'              : (make_two_particles_on_string ,[False]),     # Tuple containing data information. Can either be a tuple of form (data_gen, *data_gen_args) to generate the data or tuple (p_mask, x, p, q)
    'yield_every'       : 10,                                               # How often the simulation yields data. 
    'yield_steps'       : 1_000,                                             # How many data-yields we want. Total number of timesteps is yield_every * yield_steps

    # Metasimulational parameters
    'device'            : 'cpu',           # Device to run the simulation on. 'cuda' or 'cpu'
    'dtype'             : torch.float,      # Data type for tensors. Either float32 or float64
    'random_seed'       : 42,               # Random seed for the simulation

    # Proliferation parameters
    'prolif_rate'       : [0.00000, 0.00000],           # Cell division probabilities
    'prolif_delay'      : 0,                # Timesteps before the cells begin proliferating
    'max_cells'         : 10_000,           # Maximum number of cells in the simulation. When this number is reached the simulation terminates

    # Main model parameters
    'lambdas'           : [[0., 0.8, 0.2, 0.0],
                           [0., 0.8, 0.2, 0.0],
                           [0., 0.8, 0.2, 0.0]],                # Lambda parameters for the simulation
    'etas'              : [0.000, 0.000],                       # Noise level for the simulation
    'alpha_params'      : [[(0.0, 'locked'), (0.0, 'locked')],
                           [(0.0, 'locked'), (0.0, 'locked')]],                     # Alpha parameters for the simulation
    'alpha_range'       : 45,                                                       # Range for alpha parameters
    'gamma_params'      : [(1., 'locked'), (1.5, 'locked')],                           # Gamma parameters for the simulation
    'gamma_range'       : 1.5,                      # Range for gamma parameters
    'gamma_mean_bool'   : False,                    # Whether to use the mean of gamma_i and gamma_j for interactions or just gamma_i
    'cell_wall_interaction' : 0.0,                  # Strength of cell-wall interactions. 0 for no interaction, 1 for same strength as cell-cell interactions
    'dt'                : 0.2,                      # Time step for the simulation

    # Boundary parameters                                                                                                                                                                                                                                     
    'bound_type'        : None,
    'bound_extents'     : [24, 4],
    'bound_move_times'  : [3_000, 17_000],
    'bound_continuity'  : 5_000,

    # Stretching parameters
    'stretch_factor'     : 0.02,
    
    # cell distance parameters  # Maximum distance for interactions.
    'offsets'        : [[0, 0], [0, 0]],         
    'interaction_dist'  : 3.0,                            

    # Miscellaneous
    'notes'             : f'shit_still_fucked_yo_2_electric_boogaloo',  # Notes about the simulation. Will be printed when the simulation starts if verbose and will also be saved in .json output
    'verbose'           : True,                                         # Verbosity level for the simulation. Set off when debugging
    }

run_simulation(sim_dict=sim_dict)                           # Let's run the simulation
# Out:
# Using data generation function
# Starting simulation with notes:
# shit_still_fucked_yo_2_electric_boogaloo
# Found max safe batch size: 512
# Using batch size: 512 for true neighbor search.
# d tensor([[2.],
#         [2.]], grad_fn=<SqrtBackward0>)
# d tensor([[2.4338],   (1000 of 10000)   (2 cells)
#         [2.4338]], grad_fn=<SqrtBackward0>)
# d tensor([[2.4338],   (2000 of 10000)   (2 cells)
#         [2.4338]], grad_fn=<SqrtBackward0>)
# d tensor([[2.4338],   (3000 of 10000)   (2 cells)
#         [2.4338]], grad_fn=<SqrtBackward0>)
# d tensor([[2.4338],   (4000 of 10000)   (2 cells)
#         [2.4338]], grad_fn=<SqrtBackward0>)
# d tensor([[2.4338],   (5000 of 10000)   (2 cells)
#         [2.4338]], grad_fn=<SqrtBackward0>)
# d tensor([[2.4338],   (6000 of 10000)   (2 cells)
#         [2.4338]], grad_fn=<SqrtBackward0>)
# d tensor([[2.4338],   (7000 of 10000)   (2 cells)
#         [2.4338]], grad_fn=<SqrtBackward0>)
# d tensor([[2.4338],   (8000 of 10000)   (2 cells)
#         [2.4338]], grad_fn=<SqrtBackward0>)
# d tensor([[2.4338],   (9000 of 10000)   (2 cells)
#         [2.4338]], grad_fn=<SqrtBackward0>)
# Simulation done, saved 1000 datapoints)   (2 cells)
# Took 8.597367763519287 seconds

# %%
from modelMoarGamma import *

# %%
N = 5_00                # Number of cells in the simulation
R = (N/5)**(1/2)            # Radius of initial cell distribution
stretch_frac    = 0.15       # Fraction of type 0 cells if using make_random_sphere() cell generation function

# Simulation parameters
sim_dict = {
    # Data and output
    'output_folder'     : "gamma_absadd_50",                                 # Output folder for simulation data
    'data'              : (make_sphere_surface_stretch ,[N, stretch_frac, True, R]),     # Tuple containing data information. Can either be a tuple of form (data_gen, *data_gen_args) to generate the data or tuple (p_mask, x, p, q)
    'yield_every'       : 50,                                               # How often the simulation yields data. 
    'yield_steps'       : 1_000,                                             # How many data-yields we want. Total number of timesteps is yield_every * yield_steps

    # Metasimulational parameters
    'device'            : 'cuda',           # Device to run the simulation on. 'cuda' or 'cpu'
    'dtype'             : torch.float,      # Data type for tensors. Either float32 or float64
    'random_seed'       : 42,               # Random seed for the simulation

    # Proliferation parameters
    'prolif_rate'       : [0.00000, 0.00000],           # Cell division probabilities
    'prolif_delay'      : 0,                # Timesteps before the cells begin proliferating
    'max_cells'         : 10_000,           # Maximum number of cells in the simulation. When this number is reached the simulation terminates

    # Main model parameters
    'lambdas'           : [[0., 0.8, 0.2, 0.0],
                           [0., 0.8, 0.2, 0.0],
                           [0., 0.8, 0.2, 0.0]],                # Lambda parameters for the simulation
    'etas'              : [0.000, 0.000],                       # Noise level for the simulation
    'alpha_params'      : [[(0.0, 'locked'), (0.0, 'locked')],
                           [(0.0, 'locked'), (0.0, 'locked')]],                     # Alpha parameters for the simulation
    'alpha_range'       : 45,                                                       # Range for alpha parameters
    'gamma_params'      : [(1.5, 'locked'), (1.0/1.5, 'locked')],                           # Gamma parameters for the simulation
    'gamma_range'       : 1.5,                      # Range for gamma parameters
    'cell_wall_interaction' : 0.0,                  # Strength of cell-wall interactions. 0 for no interaction, 1 for same strength as cell-cell interactions
    'dt'                : 0.2,                      # Time step for the simulation

    # Boundary parameters                                                                                                                                                                                                                                     
    'bound_type'        : None,
    'bound_extents'     : [24, 4],
    'bound_move_times'  : [3_000, 17_000],
    'bound_continuity'  : 5_000,

    # Stretching parameters
    'stretch_factor'     : 0.02,
    
    # cell distance parameters
    'interaction_dist'  : 3.0,                              # Maximum distance for interactions.
    'offsets'        : [[0, 0], [0, 0]],         

    # Miscellaneous
    'notes'             : f'shit_still_fucked_yo_2_electric_boogaloo',  # Notes about the simulation. Will be printed when the simulation starts if verbose and will also be saved in .json output
    'verbose'           : True,                                         # Verbosity level for the simulation. Set off when debugging
    }

run_simulation(sim_dict=sim_dict)                           # Let's run the simulation
# Out:
# Using data generation function
# Starting simulation with notes:
# shit_still_fucked_yo_2_electric_boogaloo
# Found max safe batch size: 2048
# Using batch size: 2048 for true neighbor search.
# Running 3 of 1000   (150 of 50000)   (500 cells)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 54
#       5 # Simulation parameters
#       6 sim_dict = {
#       7     # Data and output
#       8     'output_folder'     : "gamma_absadd_50",                                 # Output folder for simulation data
#    (...)
#      51     'verbose'           : True,                                         # Verbosity level for the simulation. Set off when debugging
#      52     }
# ---> 54 run_simulation(sim_dict=sim_dict)                           # Let's run the simulation
#
# File ~/Desktop/dynamicCellModel/dynamicCellModel/code/modelMoarGamma.py:1080, in run_simulation(sim_dict)
#    1077 t1 = time() # We timing stuff
#    1079 # Saving data at intervals specified by yield_every:
# -> 1080 for xx, pp, qq, pp_mask, alpha_parpar, alpha_perpperp, gammagamma, energyenergy in itertools.islice(runner, yield_steps):
#    1081     i += 1
#    1082     if verbose:
#
# File ~/Desktop/dynamicCellModel/dynamicCellModel/code/modelMoarGamma.py:761, in Simulation.simulation(self, x, p, q, p_mask, alpha_par, alpha_perp, gamma)
#     759 tstep = 0
#     760 while True:
# --> 761     x, p, q, p_mask, alpha_par, alpha_perp, gamma, energy = self.time_step(x, p, q, p_mask, alpha_par, alpha_perp, gamma, tstep)        #Advancing the simulation one timestep
#     763     tstep += 1
#     764     self.tstep = tstep
#
# File ~/Desktop/dynamicCellModel/dynamicCellModel/code/modelMoarGamma.py:709, in Simulation.time_step(self, x, p, q, p_mask, alpha_par, alpha_perp, gamma, tstep)
#     706 q[p_mask == i] += -q.grad[p_mask == i] * self.dt + eta * torch.empty(*q[p_mask == i].shape, dtype=self.dtype, device=self.device).normal_() * self.sqrt_dt
#     708 # Updating alpha and gamma if they are free
# --> 709 if self.alpha_par_bool_lst[i]:
#     710     alpha_par[p_mask == i] += -alpha_par.grad[p_mask == i] * self.dt + eta * torch.empty(*alpha_par[p_mask == i].shape, dtype=self.dtype, device=self.device).normal_() * self.sqrt_dt
#     711     alpha_par[p_mask == i] = torch.clamp(alpha_par[p_mask == i], self.alpha_range[0], self.alpha_range[1])
#
# KeyboardInterrupt:
