# %% [markdown]
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from modelAreaCons import *

# %%
for gamma_pen in [1]:    
    N = 5_00                # Number of cells in the simulation
    R = (N/5)**(1/2)            # Radius of initial cell distribution
    stretch_frac    = 0.15       # Fraction of type 0 cells if using make_random_sphere() cell generation function

    # Simulation parameters
    sim_dict = {
        # Data and output
        'output_folder'     : f"stretch_gamma_pen_{gamma_pen}_qi",                                 # Output folder for simulation data
        'data'              : (make_sphere_surface_stretch ,[N, stretch_frac, True, R]),     # Tuple containing data information. Can either be a tuple of form (data_gen, *data_gen_args) to generate the data or tuple (p_mask, x, p, q)
        'yield_every'       : 50,                                               # How often the simulation yields data. 
        'yield_steps'       : 2_000,                                             # How many data-yields we want. Total number of timesteps is yield_every * yield_steps

        # Metasimulational parameters
        'device'            : 'cuda',           # Device to run the simulation on. 'cuda' or 'cpu'
        'dtype'             : torch.float,      # Data type for tensors. Either float32 or float64
        'random_seed'       : 42,               # Random seed for the simulation

        # Proliferation parameters
        'prolif_rate'       : [0.00000, 0.00000],           # Cell division probabilities
        'prolif_delay'      : 0,                # Timesteps before the cells begin proliferating
        'max_cells'         : 10_000,           # Maximum number of cells in the simulation. When this number is reached the simulation terminates

        # Main model parameters
        'lambdas'           : [[0., 0.8, 0.2, 0.0],
                            [0., 0.8, 0.2, 0.0],
                            [0., 0.8, 0.2, 0.0]],                # Lambda parameters for the simulation
        'etas'              : [0.0005, 0.0005],                       # Noise level for the simulation
        'alpha_params'      : [[(0.0, 'locked'), (0.0, 'locked')],
                            [(0.0, 'locked'), (0.0, 'locked')]],                     # Alpha parameters for the simulation
        'alpha_range'       : 45,                                                       # Range for alpha parameters
        'gamma_params'      : [[(1.0, 'free'), (1.0, 'free')],
                            [(1.0, 'free'), (1.0, 'free')]],                           # Gamma parameters for the simulation
        'target_A'          : 10.5 / 3,                      # Target area for the cells. Only relevant if lambda_area is not 0
        'penalize_A'        : gamma_pen,                       # Whether to penalize deviations from the target area. Only relevant if lambda_area is not 0 
        'gamma_range'       : 1.5,                      # Range for gamma parameters
        'cell_wall_interaction' : 0.0,                  # Strength of cell-wall interactions. 0 for no interaction, 1 for same strength as cell-cell interactions
        'dt'                : 0.2,                      # Time step for the simulation

        # Boundary parameters                                                                                                                                                                                                                                     
        'bound_type'        : None,
        'bound_extents'     : [24, 4],
        'bound_move_times'  : [3_000, 17_000],
        'bound_continuity'  : 5_000,

        # Stretching parameters
        'stretch_factor'     : 0.02,
        
        # cell distance parameters
        'interaction_dist'  : 3.0,                              # Maximum distance for interactions.
        'offsets'        : [[0, 0], [0, 0]],         

        # Miscellaneous
        'notes'             : f'shit_still_fucked_yo_2_electric_boogaloo',  # Notes about the simulation. Will be printed when the simulation starts if verbose and will also be saved in .json output
        'verbose'           : True,                                         # Verbosity level for the simulation. Set off when debugging
        }

    run_simulation(sim_dict=sim_dict)                           # Let's run the simulation
# Out:
# Using data generation function
# Starting simulation with notes:
# shit_still_fucked_yo_2_electric_boogaloo
# Found max safe batch size: 2048
# Using batch size: 2048 for true neighbor search.
# Running 292 of 2000   (14600 of 100000)   (500 cells)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 58
#       6 # Simulation parameters
#       7 sim_dict = {
#       8     # Data and output
#       9     'output_folder'     : f"stretch_gamma_pen_{gamma_pen}_qi",                                 # Output folder for simulation data
#    (...)
#      55     'verbose'           : True,                                         # Verbosity level for the simulation. Set off when debugging
#      56     }
# ---> 58 run_simulation(sim_dict=sim_dict)                           # Let's run the simulation
#
# File ~/Desktop/dynamicCellModel/dynamicCellModel/code/modelAreaCons.py:1204, in run_simulation(sim_dict)
#    1201 t1 = time() # We timing stuff
#    1203 # Saving data at intervals specified by yield_every:
# -> 1204 for xx, pp, qq, pp_mask, alpha_parpar, alpha_perpperp, gamma_parpar, gamma_perpperp, energyenergy, areaarea in itertools.islice(runner, yield_steps):
#    1205     i += 1
#    1206     if verbose:
#
# File ~/Desktop/dynamicCellModel/dynamicCellModel/code/modelAreaCons.py:881, in Simulation.simulation(self, x, p, q, p_mask, alpha_par, alpha_perp, gamma_par, gamma_perp)
#     879 tstep = 0
#     880 while True:
# --> 881     x, p, q, p_mask, alpha_par, alpha_perp, gamma_par, gamma_perp, energy, area = self.time_step(x, p, q, p_mask, alpha_par, alpha_perp, gamma_par, gamma_perp, tstep)        #Advancing the simulation one timestep
#     883     tstep += 1
#     884     self.tstep = tstep
#
# File ~/Desktop/dynamicCellModel/dynamicCellModel/code/modelAreaCons.py:819, in Simulation.time_step(self, x, p, q, p_mask, alpha_par, alpha_perp, gamma_par, gamma_perp, tstep)
#     817 x[p_mask == i] += -x.grad[p_mask == i] * self.dt + eta * torch.empty(*x[p_mask == i].shape, dtype=self.dtype, device=self.device).normal_() * self.sqrt_dt
#     818 p[p_mask == i] += -p.grad[p_mask == i] * self.dt + eta * torch.empty(*p[p_mask == i].shape, dtype=self.dtype, device=self.device).normal_() * self.sqrt_dt
# --> 819 q[p_mask == i] += -q.grad[p_mask == i] * self.dt + eta * torch.empty(*q[p_mask == i].shape, dtype=self.dtype, device=self.device).normal_() * self.sqrt_dt
#     821 # Updating alpha and gamma if they are free
#     822 if self.alpha_par_bool_lst[i]:
#
# KeyboardInterrupt:

# %%
# # from modelMoarGamma import *
# from modelTestGammai2cells import *

# %% [markdown]
# ### Running the simulation

# %%
# N = 5_00                # Number of cells in the simulation
# R = (N/5)**(1/2)            # Radius of initial cell distribution
# stretch_frac    = 0.15       # Fraction of type 0 cells if using make_random_sphere() cell generation function

# # Simulation parameters
# sim_dict = {
#     # Data and output
#     'output_folder'     : "eq_gammamean",                                 # Output folder for simulation data
#     'data'              : (make_two_particles_on_string ,[False]),     # Tuple containing data information. Can either be a tuple of form (data_gen, *data_gen_args) to generate the data or tuple (p_mask, x, p, q)
#     'yield_every'       : 10,                                               # How often the simulation yields data. 
#     'yield_steps'       : 1_000,                                             # How many data-yields we want. Total number of timesteps is yield_every * yield_steps

#     # Metasimulational parameters
#     'device'            : 'cpu',           # Device to run the simulation on. 'cuda' or 'cpu'
#     'dtype'             : torch.float,      # Data type for tensors. Either float32 or float64
#     'random_seed'       : 42,               # Random seed for the simulation

#     # Proliferation parameters
#     'prolif_rate'       : [0.00000, 0.00000],           # Cell division probabilities
#     'prolif_delay'      : 0,                # Timesteps before the cells begin proliferating
#     'max_cells'         : 10_000,           # Maximum number of cells in the simulation. When this number is reached the simulation terminates

#     # Main model parameters
#     'lambdas'           : [[0., 0.8, 0.2, 0.0],
#                            [0., 0.8, 0.2, 0.0],
#                            [0., 0.8, 0.2, 0.0]],                # Lambda parameters for the simulation
#     'etas'              : [0.000, 0.000],                       # Noise level for the simulation
#     'alpha_params'      : [[(0.0, 'locked'), (0.0, 'locked')],
#                            [(0.0, 'locked'), (0.0, 'locked')]],                     # Alpha parameters for the simulation
#     'alpha_range'       : 45,                                                       # Range for alpha parameters
#     'gamma_params'      : [(1., 'locked'), (1.5, 'locked')],                           # Gamma parameters for the simulation
#     'gamma_range'       : 1.5,                      # Range for gamma parameters
#     'gamma_mean_bool'   : False,                    # Whether to use the mean of gamma_i and gamma_j for interactions or just gamma_i
#     'cell_wall_interaction' : 0.0,                  # Strength of cell-wall interactions. 0 for no interaction, 1 for same strength as cell-cell interactions
#     'dt'                : 0.2,                      # Time step for the simulation

#     # Boundary parameters                                                                                                                                                                                                                                     
#     'bound_type'        : None,
#     'bound_extents'     : [24, 4],
#     'bound_move_times'  : [3_000, 17_000],
#     'bound_continuity'  : 5_000,

#     # Stretching parameters
#     'stretch_factor'     : 0.02,
    
#     # cell distance parameters  # Maximum distance for interactions.
#     'offsets'        : [[0, 0], [0, 0]],         
#     'interaction_dist'  : 3.0,                            

#     # Miscellaneous
#     'notes'             : f'shit_still_fucked_yo_2_electric_boogaloo',  # Notes about the simulation. Will be printed when the simulation starts if verbose and will also be saved in .json output
#     'verbose'           : True,                                         # Verbosity level for the simulation. Set off when debugging
#     }

# run_simulation(sim_dict=sim_dict)                           # Let's run the simulation

# %%
from modelMoarGamma import *

# %%
N = 5_00                # Number of cells in the simulation
R = (N/5)**(1/2)            # Radius of initial cell distribution
stretch_frac    = 0.1       # Fraction of type 0 cells if using make_random_sphere() cell generation function

# Simulation parameters
sim_dict = {
    # Data and output
    'output_folder'     : "other_model_comp_2",                                 # Output folder for simulation data
    'data'              : (make_sphere_surface_stretch ,[N, stretch_frac, True, R]),     # Tuple containing data information. Can either be a tuple of form (data_gen, *data_gen_args) to generate the data or tuple (p_mask, x, p, q)
    'yield_every'       : 50,                                               # How often the simulation yields data. 
    'yield_steps'       : 1_000,                                             # How many data-yields we want. Total number of timesteps is yield_every * yield_steps

    # Metasimulational parameters
    'device'            : 'cuda',           # Device to run the simulation on. 'cuda' or 'cpu'
    'dtype'             : torch.float,      # Data type for tensors. Either float32 or float64
    'random_seed'       : 42,               # Random seed for the simulation

    # Proliferation parameters
    'prolif_rate'       : [0.00000, 0.00000],           # Cell division probabilities
    'prolif_delay'      : 0,                # Timesteps before the cells begin proliferating
    'max_cells'         : 10_000,           # Maximum number of cells in the simulation. When this number is reached the simulation terminates

    # Main model parameters
    'lambdas'           : [[0., 0.8, 0.2, 0.0],
                           [0., 0.8, 0.2, 0.0],
                           [0., 0.8, 0.2, 0.0]],                # Lambda parameters for the simulation
    'etas'              : [0.005, 0.005],                       # Noise level for the simulation
    'alpha_params'      : [[(0.0, 'locked'), (0.0, 'locked')],
                           [(0.0, 'locked'), (0.0, 'locked')]],                     # Alpha parameters for the simulation
    'alpha_range'       : 45,                                                       # Range for alpha parameters
    'gamma_params'      : [(1.0, 'locked'), (1.0, 'locked')],                           # Gamma parameters for the simulation
    'gamma_range'       : 1.5,                      # Range for gamma parameters
    'cell_wall_interaction' : 0.0,                  # Strength of cell-wall interactions. 0 for no interaction, 1 for same strength as cell-cell interactions
    'dt'                : 0.2,                      # Time step for the simulation

    # Boundary parameters                                                                                                                                                                                                                                     
    'bound_type'        : None,
    'bound_extents'     : [24, 4],
    'bound_move_times'  : [3_000, 17_000],
    'bound_continuity'  : 5_000,

    # Stretching parameters
    'stretch_factor'     : 0.00,
    
    # cell distance parameters
    'interaction_dist'  : 3.0,                              # Maximum distance for interactions.
    'offsets'        : [[0, 0], [0, 0]],         

    # Miscellaneous
    'notes'             : f'shit_still_fucked_yo_2_electric_boogaloo',  # Notes about the simulation. Will be printed when the simulation starts if verbose and will also be saved in .json output
    'verbose'           : True,                                         # Verbosity level for the simulation. Set off when debugging
    }

run_simulation(sim_dict=sim_dict)                           # Let's run the simulation
# Out:
# Using data generation function
# Starting simulation with notes:
# shit_still_fucked_yo_2_electric_boogaloo
# Found max safe batch size: 2048
# Using batch size: 2048 for true neighbor search.
# Running 468 of 1000   (23400 of 50000)   (500 cells)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 54
#       5 # Simulation parameters
#       6 sim_dict = {
#       7     # Data and output
#       8     'output_folder'     : "other_model_comp_2",                                 # Output folder for simulation data
#    (...)
#      51     'verbose'           : True,                                         # Verbosity level for the simulation. Set off when debugging
#      52     }
# ---> 54 run_simulation(sim_dict=sim_dict)                           # Let's run the simulation
#
# File ~/Desktop/dynamicCellModel/dynamicCellModel/code/modelMoarGamma.py:1080, in run_simulation(sim_dict)
#    1077 t1 = time() # We timing stuff
#    1079 # Saving data at intervals specified by yield_every:
# -> 1080 for xx, pp, qq, pp_mask, alpha_parpar, alpha_perpperp, gammagamma, energyenergy in itertools.islice(runner, yield_steps):
#    1081     i += 1
#    1082     if verbose:
#
# File ~/Desktop/dynamicCellModel/dynamicCellModel/code/modelMoarGamma.py:761, in Simulation.simulation(self, x, p, q, p_mask, alpha_par, alpha_perp, gamma)
#     759 tstep = 0
#     760 while True:
# --> 761     x, p, q, p_mask, alpha_par, alpha_perp, gamma, energy = self.time_step(x, p, q, p_mask, alpha_par, alpha_perp, gamma, tstep)        #Advancing the simulation one timestep
#     763     tstep += 1
#     764     self.tstep = tstep
#
# File ~/Desktop/dynamicCellModel/dynamicCellModel/code/modelMoarGamma.py:695, in Simulation.time_step(self, x, p, q, p_mask, alpha_par, alpha_perp, gamma, tstep)
#     692 d, dx, idx, z_mask = self.get_neighbors_vor(x, p, q, gamma, k=self.k)
#     694 # Calculate potential
# --> 695 V, Vi = self.potential(x, p, q, p_mask,
#     696                     alpha_par, alpha_perp, gamma,
#     697                     d, dx, idx, z_mask)
#     699 # Backpropagation
#     700 V.backward()
#
# File ~/Desktop/dynamicCellModel/dynamicCellModel/code/modelMoarGamma.py:489, in Simulation.potential(self, x, p, q, p_mask, alpha_par, alpha_perp, gamma, d, dx, idx, z_mask)
#     486 interaction_mask = p_mask[:,None].expand(p_mask.shape[0], idx.shape[1]) + p_mask[idx]   # Making the interaction mask. A tool for constructing a lambda tensor
#     488 # Filling a lambda array with the right interactions
# --> 489 l = torch.zeros(size=(interaction_mask.shape[0], interaction_mask.shape[1], 4),
#     490             device=self.device, dtype=self.dtype)   # Empty lambda tensor
#     491 repulsion_mask_lst = []
#     493 for i in range(3):                                          # We loop through the 3 interaction types (type0-type0, type0-type1, type1-type1)
#
# KeyboardInterrupt:
